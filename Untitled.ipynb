# %%
# test_qwen2_5_dymem_infer.py
import os
os.environ["TORCH_COMPILE_DISABLE"] = "1"
os.environ["PYTORCH_CUDA_GRAPH_DISABLE"] = "1"
from pickle import FALSE
import torch
from transformers import AutoConfig, AutoTokenizer, AutoModelForCausalLM
from dymem.transformer.qwen2_dymem import register_customized_qwen2, Qwen2Config, Qwen2ForCausalLM
from dymem.utils import CacheWithMem
register_customized_qwen2(exist_ok=True)
device = torch.device(os.environ.get("CUDA_DEVICE", "cuda:4") if torch.cuda.is_available() else "cpu")
if torch.cuda.is_available():
    torch.cuda.set_device(device)

# %%
MODEL_DIR = "/home/xiaoyonggao/dymem/Exp_model/qwen3B-inst-simpC4B1-res-new"
# MODEL_DIR = "Qwen/Qwen2.5-3B-Instruct"
model = AutoModelForCausalLM.from_pretrained(MODEL_DIR, dtype=torch.bfloat16).to(device)
tok = AutoTokenizer.from_pretrained(MODEL_DIR, use_fast=True)
model.eval()
# ==== 6) Tokenizer ====
if tok.pad_token is None:
    tok.pad_token = tok.eos_token
    tok.pad_token_id = tok.eos_token_id
# Out:
# Sliding Window Attention is enabled but not implemented for `sdpa`; unexpected results may be encountered.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
def _format_token_label(token: str, max_len: int = 24) -> str:
    if token is None:
        return ""
    t = token
    if t == " ":
        t = "␠"
    if len(t) > 0 and t[0] in ("▁", "Ġ"):
        t = "␠" + t[1:]
    if t == "\n":
        t = "\\n"
    if t == "\t":
        t = "\\t"
    if max_len is not None and len(t) > max_len:
        t = t[: max_len - 1] + "…"
    return t


def _decode_token_piece(tok, token_id: int) -> str:
    try:
        s = tok.decode([int(token_id)], skip_special_tokens=False, clean_up_tokenization_spaces=False)
    except TypeError:
        s = tok.decode([int(token_id)], skip_special_tokens=False)
    if s is None:
        return ""
    return s


def _print_tokens_around_mem(tok, input_ids, sink_len: int, sliding_window: int, radius: int = 24):
    ids = input_ids.detach().cpu().tolist()
    tokens = tok.convert_ids_to_tokens(ids, skip_special_tokens=False)

    if sliding_window is None:
        sliding_window = 0
    sliding_window = int(sliding_window)
    sink_len = int(sink_len)

    if sliding_window > 0:
        window_start = max(sink_len + 1, len(tokens) - sliding_window)
        window_tokens = tokens[window_start:]
        window_ids = ids[window_start:]
    else:
        window_start = sink_len + 1
        window_tokens = []
        window_ids = []

    start = max(0, sink_len - radius)
    end = sink_len + radius + 1

    print("\n=== TOKENS AROUND [mem] (key index space) ===")
    print(f"sink_len={sink_len}  sliding_window={sliding_window}  input_len={len(tokens)}  window_start={window_start}")
    for key_idx in range(start, end):
        if key_idx < sink_len:
            token = tokens[key_idx] if key_idx < len(tokens) else ""
            token_id = ids[key_idx] if key_idx < len(ids) else None
            src_pos = key_idx
        elif key_idx == sink_len:
            token = "[mem]"
            token_id = None
            src_pos = None
        else:
            j = key_idx - (sink_len + 1)
            token = window_tokens[j] if 0 <= j < len(window_tokens) else ""
            token_id = window_ids[j] if 0 <= j < len(window_ids) else None
            src_pos = (window_start + j) if 0 <= j < len(window_tokens) else None

        decoded = "" if token_id is None else _decode_token_piece(tok, token_id)
        display = token if decoded == "" else decoded
        src = "None" if src_pos is None else str(src_pos)
        print(f"key[{key_idx:5d}]  src[{src:>5}]  {_format_token_label(display)}")

# %%
with open('/home/xiaoyonggao/dymem/examples/scripts/test4.txt', 'r') as f:
    prompt = f.read()
messages = [
  {"role": "system", "content": "You are Qwen-Compressor, created by yg Xiao. You will use the compressed mem token to help you answer the user's question. You are a helpful assistant."},
  {"role": "user", "content": f"{prompt}"}
]
inputs = tok.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
# inputs = "In the summer of 1995, my friend Robert Morris and I started a startup called Viaweb. Our plan was to write software "
inputs = tok(inputs, return_tensors="pt").to(device)
input_len = inputs["input_ids"].shape[-1]
input_len,messages[1]['content'][:1000]
# Out:
# (4029,
#  '111 222 333 444 555 666 777 888 999 100 111 222 333 444 555 666 777 888 9111222 112 Mem:[In the summer of 1995, my friend Robert Morris and I started a startup called Viaweb. Our plan was to write software that would let end users build stores. What was novel about this software, at the time, was that it ran on our server, using ordinary Web pages as the interface.”]22 333 444 555 666 777 888 999 100111 222 333 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 ')

# %%
model.config.sliding_window = input_len-128-65
# model.config.sliding_window = 3000
with torch.no_grad():
    past_key_values = CacheWithMem(model.config, dtype=torch.bfloat16, device=device)
    _print_tokens_around_mem(
        tok,
        inputs["input_ids"][0],
        sink_len=getattr(model.config, "num_attn_sinks", 128),
        sliding_window=getattr(model.config, "sliding_window", None),
        radius=10,
    )
    output = model.generate(
        **inputs,
        max_new_tokens=128,
        num_beams=1,
        use_cache=True,
        do_sample=False,
        # temperature=0.7,
        past_key_values=past_key_values,
    )[0]
    # pred = tok.decode(output[input_len:], skip_special_tokens=True)
    pred = tok.decode(output[:], skip_special_tokens=True)
print(f"\n=== GENERATION ===\n{pred}\n")
print(f"\n输入长度:{input_len} ｜ 输出长度：{output.shape[-1]}")
# Out:
# === TOKENS AROUND [mem] (key index space) ===
# sink_len=128  sliding_window=3836  input_len=4029  window_start=193
# key[  118]  src[  118]  1
# key[  119]  src[  119]  2
# key[  120]  src[  120]  2
# key[  121]  src[  121]  2
# key[  122]  src[  122]  ␠
# key[  123]  src[  123]  1
# key[  124]  src[  124]  1
# key[  125]  src[  125]  2
# key[  126]  src[  126]   Mem
# key[  127]  src[  127]  :[
# key[  128]  src[ None]  [mem]
# key[  129]  src[  193]  ]
# key[  130]  src[  194]  2
# key[  131]  src[  195]  2
# key[  132]  src[  196]  ␠
# key[  133]  src[  197]  3
# key[  134]  src[  198]  3
# key[  135]  src[  199]  3
# key[  136]  src[  200]  ␠
# key[  137]  src[  201]  4
# key[  138]  src[  202]  4
#
# === GENERATION ===
# system
# You are Qwen-Compressor, created by yg Xiao. You will use the compressed mem token to help you answer the user's question. You are a helpful assistant.
# user
# 111 222 333 444 555 666 777 888 999 100 111 222 333 444 555 666 777 888 9111222 112 Mem:[In the summer of 1995, my friend Robert Morris and I started a startup called Viaweb. Our plan was to write software that would let end users build stores. What was novel about this software, at the time, was that it ran on our server, using ordinary Web pages as the interface.”]22 333 444 555 666 777 888 999 100111 222 333 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100 111 222 333 444 555 666 777 888 999 100 111 222 333 444 555 666 777 888 999 100 111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 100111 222 333 444 555 666 777 888 999 10011 ...
# The Mem is?
# assistant
# The Mem token contains the sequence "222 333 444 555 666 777 888 999" repeated multiple times, followed by "111 222 333 444 555 666 777 888 9111222 112". This pattern repeats throughout the given string of numbers.
#
#
# 输入长度:4029 ｜ 输出长度：4130

# %%
for i in past_key_values.mem_hidden:
    print(i.norm(dim=1,p=1).item())
# Out:
# 936.0
# 1264.0
# 1928.0
# 1896.0
# 2080.0
# 2240.0
# 2736.0
# 2624.0
# 2624.0
# 2624.0
# 2528.0
# 2848.0
# 2816.0
# 2624.0
# 2784.0
# 2656.0
# 2496.0
# 2480.0
# 2480.0
# 2624.0
# 2864.0
# 2800.0
# 2736.0
# 2592.0
# 2592.0
# 2528.0
# 2544.0
# 2544.0
# 2784.0
# 2944.0
# 3376.0
# 3968.0
# 4640.0
# 4608.0
# 5696.0
# 8064.0

# %%
def rotate_half(x):
    x1 = x[..., : x.shape[-1] // 2]
    x2 = x[..., x.shape[-1] // 2 :]
    return torch.cat((-x2, x1), dim=-1)
def apply_rotary_pos_emb(q, k, cos, sin, position_ids=None, unsqueeze_dim=1):
    cos = cos.unsqueeze(unsqueeze_dim)
    sin = sin.unsqueeze(unsqueeze_dim)
    q_embed = (q * cos) + (rotate_half(q) * sin)
    k_embed = (k * cos) + (rotate_half(k) * sin)
    return q_embed, k_embed

    
mem_hidden_shape = (1, 1, -1, 128)
pos_emb = model.model.rotary_emb(past_key_values.mem_hidden[0],torch.tensor([[128]]).cuda())
for l,i in enumerate(past_key_values.mem_bank):
    # print(i.norm(dim=2,p=2).item())
    q_mem = model.model.layers[0].self_attn.q_proj(i).view(mem_hidden_shape).transpose(1, 2)
    k_mem = model.model.layers[0].self_attn.k_proj(i).view(mem_hidden_shape).transpose(1, 2)
    v_mem = model.model.layers[0].self_attn.v_proj(i).view(mem_hidden_shape).transpose(1, 2)
    q_mem,k_mem = apply_rotary_pos_emb(q_mem,k_mem,*pos_emb)
    k_mem_norm = k_mem.norm(dim=3,p=1).mean().item()
    v_mem_norm = v_mem.norm(dim=3,p=1).mean().item()
    k_nrom = past_key_values.layers[l].keys[:,:,-1:,:].norm(dim=3,p=1).mean().item()
    v_nrom = past_key_values.layers[l].values[:,:,-1:,:].norm(dim=3,p=1).mean().item()
    print(f"[layer {l}]:V:{{ v_mem:{v_mem_norm}\t,v_normal:{v_nrom} }} \t|\tK{{k_mem:{k_mem_norm}\t,k_normal:{k_nrom} }}")
# past_key_values.layers[0].values[:,:,-1:,:].shape
# Out:
# [layer 0]:V:{ v_mem:78.0	,v_normal:11.625 } 	|	K{k_mem:868.0	,k_normal:744.0 }
# [layer 1]:V:{ v_mem:78.5	,v_normal:14.625 } 	|	K{k_mem:844.0	,k_normal:316.0 }
# [layer 2]:V:{ v_mem:75.0	,v_normal:15.875 } 	|	K{k_mem:864.0	,k_normal:268.0 }
# [layer 3]:V:{ v_mem:81.0	,v_normal:33.0 } 	|	K{k_mem:856.0	,k_normal:133.0 }
# [layer 4]:V:{ v_mem:82.0	,v_normal:36.5 } 	|	K{k_mem:848.0	,k_normal:150.0 }
# [layer 5]:V:{ v_mem:80.0	,v_normal:42.5 } 	|	K{k_mem:872.0	,k_normal:154.0 }
# [layer 6]:V:{ v_mem:77.0	,v_normal:41.75 } 	|	K{k_mem:856.0	,k_normal:143.0 }
# [layer 7]:V:{ v_mem:75.0	,v_normal:56.5 } 	|	K{k_mem:856.0	,k_normal:125.0 }
# [layer 8]:V:{ v_mem:72.0	,v_normal:62.25 } 	|	K{k_mem:880.0	,k_normal:114.0 }
# [layer 9]:V:{ v_mem:80.0	,v_normal:55.0 } 	|	K{k_mem:860.0	,k_normal:122.5 }
# [layer 10]:V:{ v_mem:78.0	,v_normal:60.75 } 	|	K{k_mem:868.0	,k_normal:124.0 }
# [layer 11]:V:{ v_mem:85.0	,v_normal:48.5 } 	|	K{k_mem:856.0	,k_normal:114.0 }
# [layer 12]:V:{ v_mem:79.0	,v_normal:46.0 } 	|	K{k_mem:872.0	,k_normal:121.0 }
# [layer 13]:V:{ v_mem:78.0	,v_normal:55.5 } 	|	K{k_mem:888.0	,k_normal:132.0 }
# [layer 14]:V:{ v_mem:79.0	,v_normal:55.25 } 	|	K{k_mem:864.0	,k_normal:145.0 }
# [layer 15]:V:{ v_mem:73.0	,v_normal:68.0 } 	|	K{k_mem:864.0	,k_normal:147.0 }
# [layer 16]:V:{ v_mem:79.0	,v_normal:44.75 } 	|	K{k_mem:856.0	,k_normal:158.0 }
# [layer 17]:V:{ v_mem:83.0	,v_normal:52.5 } 	|	K{k_mem:880.0	,k_normal:112.0 }
# [layer 18]:V:{ v_mem:76.0	,v_normal:57.0 } 	|	K{k_mem:864.0	,k_normal:152.0 }
# [layer 19]:V:{ v_mem:77.5	,v_normal:50.5 } 	|	K{k_mem:884.0	,k_normal:138.0 }
# [layer 20]:V:{ v_mem:74.0	,v_normal:67.5 } 	|	K{k_mem:844.0	,k_normal:129.0 }
# [layer 21]:V:{ v_mem:79.0	,v_normal:54.25 } 	|	K{k_mem:864.0	,k_normal:124.0 }
# [layer 22]:V:{ v_mem:80.0	,v_normal:54.75 } 	|	K{k_mem:856.0	,k_normal:122.0 }
# [layer 23]:V:{ v_mem:80.0	,v_normal:58.0 } 	|	K{k_mem:864.0	,k_normal:135.0 }
# [layer 24]:V:{ v_mem:73.5	,v_normal:66.0 } 	|	K{k_mem:856.0	,k_normal:139.0 }
# [layer 25]:V:{ v_mem:83.0	,v_normal:67.5 } 	|	K{k_mem:896.0	,k_normal:109.5 }
# [layer 26]:V:{ v_mem:77.0	,v_normal:66.0 } 	|	K{k_mem:888.0	,k_normal:119.0 }
# [layer 27]:V:{ v_mem:72.5	,v_normal:77.0 } 	|	K{k_mem:880.0	,k_normal:189.0 }
# [layer 28]:V:{ v_mem:75.0	,v_normal:84.0 } 	|	K{k_mem:864.0	,k_normal:143.0 }
# [layer 29]:V:{ v_mem:80.0	,v_normal:73.0 } 	|	K{k_mem:876.0	,k_normal:124.0 }
# [layer 30]:V:{ v_mem:75.0	,v_normal:82.0 } 	|	K{k_mem:864.0	,k_normal:115.0 }
# [layer 31]:V:{ v_mem:80.0	,v_normal:76.0 } 	|	K{k_mem:876.0	,k_normal:121.0 }
# [layer 32]:V:{ v_mem:85.0	,v_normal:98.5 } 	|	K{k_mem:888.0	,k_normal:110.0 }
# [layer 33]:V:{ v_mem:73.5	,v_normal:152.0 } 	|	K{k_mem:864.0	,k_normal:85.0 }
# [layer 34]:V:{ v_mem:85.0	,v_normal:105.0 } 	|	K{k_mem:864.0	,k_normal:126.5 }
# [layer 35]:V:{ v_mem:75.0	,v_normal:117.5 } 	|	K{k_mem:872.0	,k_normal:158.0 }

# %%
import torch.nn.functional as F
def analyze_mem_bank_logits(model, tokenizer, mem_bank, top_k=10):
    """
    对 mem_bank 进行 Logit Lens 分析
    mem_bank: shape [batch_size, seq_len, hidden_size] 或 [batch_size, hidden_size]
    """
    model.eval()
    with torch.no_grad():
        # 1. 必须先经过模型最后的 Layer Norm 层，否则分布会偏移
        # Qwen2 的结构通常是 model.model.norm
        hidden_states = model.model.norm(mem_bank)
        
        # 2. 映射到词表空间
        logits = model.lm_head(hidden_states)
        
        # 3. 计算概率分布
        probs = F.softmax(logits, dim=-1)
        
        # 4. 获取 Top-K 结果
        top_probs, top_indices = torch.topk(probs, k=top_k, dim=-1)
        
        # 打印结果
        # 假设我们只看第一个 batch 的最后一个 token (如果是压缩后的 single vector)
        if len(top_indices.shape) == 3:
            last_token_indices = top_indices[0, -1]
            last_token_probs = top_probs[0, -1]
        else:
            last_token_indices = top_indices[0]
            last_token_probs = top_probs[0]

        print(f"{'Rank':<5} | {'Token ID':<10} | {'Token String':<20} | {'Probability'}")
        print("-" * 60)
        for i in range(top_k):
            token_id = last_token_indices[i].item()
            token_str = tokenizer.decode([token_id])
            prob = last_token_probs[i].item()
            print(f"{i+1:<5} | {token_id:<10} | {token_str:<20} | {prob:.4f}")

# %%
analyze_mem_bank_logits(model, tok, past_key_values.mem_hidden[33],top_k=20)
# Out:
# Rank  | Token ID   | Token String         | Probability
# ------------------------------------------------------------
# 1     | 8176       |  Amazon              | 0.0157
# 2     | 16093      |  writers             | 0.0131
# 3     | 6916       |  writer              | 0.0096
# 4     | 1372       |  number              | 0.0074
# 5     | 3847       |  users               | 0.0070
# 6     | 2319       |  version             | 0.0070
# 7     | 11601      |  shipping            | 0.0060
# 8     | 11         | ,                    | 0.0053
# 9     | 24         | 9                    | 0.0047
# 10    | 19919      |  creator             | 0.0042
# 11    | 38416      |  amazon              | 0.0040
# 12    | 1707       |  style               | 0.0039
# 13    | 33799      |  creators            | 0.0039
# 14    | 117845     | 叶修                   | 0.0033
# 15    | 6604       |  reader              | 0.0027
# 16    | 12194      |  quantity            | 0.0027
# 17    | 4540       |  phone               | 0.0027
# 18    | 90273      | SenderId             | 0.0026
# 19    | 23245      |  AWS                 | 0.0024
# 20    | 291        | ed                   | 0.0024

# %%
def check_cosine_sim(target_words, mem_bank, model, tokenizer):
    embeddings = model.get_input_embeddings().weight
    # 归一化 mem_bank
    mem_norm = model.model.norm(mem_bank.view(1, -1))
    mem_norm = torch.nn.functional.normalize(mem_norm,p=2,dim=1)
    for word in target_words:
        token_id = tokenizer.encode(word, add_special_tokens=False)[0]
        word_embedding = embeddings[token_id].view(1, -1)
        word_norm = torch.nn.functional.normalize(word_embedding, p=2, dim=1)
        
        sim = torch.mm(mem_norm, word_norm.T).item()
        print(f"Cosine Similarity with '{word}': {sim:.4f}")
check_cosine_sim(["1995","Amazon","Morris","Lisp", "startup", "software", "Viaweb", "the", "and"], past_key_values.mem_hidden[35], model, tok)
# Out:
# Cosine Similarity with '1995': 0.0732
# Cosine Similarity with 'Amazon': 0.0466
# Cosine Similarity with 'Morris': -0.0024
# Cosine Similarity with 'Lisp': 0.0289
# Cosine Similarity with 'startup': 0.0087
# Cosine Similarity with 'software': 0.0037
# Cosine Similarity with 'Viaweb': -0.0017
# Cosine Similarity with 'the': 0.0500
# Cosine Similarity with 'and': 0.0383

# %%
import torch
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

def plot_semantic_evolution(target_words, mem_hidden_list, model, tokenizer):
    """
    绘制语义随层数变化的演化轨迹
    mem_hidden_list: 包含每层 mem_hidden 的列表 (例如 past_key_values.mem_hidden)
    """
    model.eval()
    embeddings = model.get_input_embeddings().weight
    results = []

    # 1. 预计算每个单词的归一化 Embedding
    word_vecs = {}
    for word in target_words:
        token_ids = tokenizer.encode(word, add_special_tokens=False)
        if not token_ids: continue
        token_id = token_ids[0]
        # L2 归一化词向量
        word_vec = torch.nn.functional.normalize(embeddings[token_id].view(1, -1), p=2, dim=1)
        word_vecs[word] = word_vec

    # 2. 逐层计算相似度
    for i, mem_bank in enumerate(mem_hidden_list):
        with torch.no_grad():
            # 必须经过 RMSNorm 映射到解码流形
            mem_hidden = model.model.norm(mem_bank.view(1, -1))
            # L2 归一化隐藏状态
            mem_unit = torch.nn.functional.normalize(mem_hidden, p=2, dim=1)
            
            for word, word_unit in word_vecs.items():
                sim = torch.mm(mem_unit, word_unit.T).item()
                results.append({"Layer": i, "Word": word, "Similarity": sim})

    # 3. 转换为 DataFrame 并绘图
    df = pd.DataFrame(results)
    plt.figure(figsize=(14, 7))
    sns.set_theme(style="whitegrid")
    
    # 区分关键词和虚词（可选，为了视觉更清晰）
    palette = sns.color_palette("husl", len(target_words))
    ax = sns.lineplot(data=df, x="Layer", y="Similarity", hue="Word", palette=palette, linewidth=2, marker='o', markersize=4)
    
    # 4. 标注关键转折层
    plt.axvline(x=33, color='red', linestyle='--', alpha=0.6, label='Layer 33 (Peak)')
    plt.text(33.5, df['Similarity'].max()*0.9, 'Semantic Peak', color='red', fontweight='bold')
    
    plt.title("Semantic Evolution of Memory Token Across Layers", fontsize=16, fontweight='bold')
    plt.xlabel("Layer Index", fontsize=12)
    plt.ylabel("Cosine Similarity (L2 Normalized)", fontsize=12)
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', title="Tokens")
    plt.tight_layout()
    plt.show()

# 调用示例
words = ["1995", "Amazon", "Morris", "Lisp", "startup", "software", "Viaweb", "the", "and"]
plot_semantic_evolution(words, past_key_values.mem_hidden, model, tok)

# %%
# 选一个正常的 token hidden state 做对比
normal_hidden = model.model.embed_tokens(torch.tensor([100]).to(model.device)) 
print(f"Normal hidden norm: {normal_hidden.norm().item()}")
print(f"Mem_bank norm: {past_key_values.mem_hidden[33].norm().item()}")
# Out:
# Normal hidden norm: 1.1640625
# Mem_bank norm: 258.0

# %%
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

def analyze_mem_hidden_similarity(mem_hidden_list):
    """
    mem_hidden_list: 包含每层 mem_hidden 的列表 [layer_0_hidden, layer_1_hidden, ...]
    每个元素的 shape 应该是 [hidden_size] 或 [1, hidden_size]
    """
    # 1. 确保所有向量都是 2D [num_layers, hidden_size]
    # 假设 hidden_size 是 4096 (Qwen2-7B)
    vectors = [v.detach().cpu().float().view(-1) for v in mem_hidden_list]
    matrix = torch.stack(vectors) # [num_layers, hidden_size]
    
    # 2. 计算余弦相似度矩阵
    # S_ij = (vi · vj) / (||vi|| * ||vj||)
    norm_matrix = F.normalize(matrix, p=2, dim=1)
    sim_matrix = torch.mm(norm_matrix, norm_matrix.T).numpy()
    
    # 3. 绘图
    plt.figure(figsize=(12, 10))
    sns.heatmap(sim_matrix, 
                cmap='viridis', 
                annot=False, 
                xticklabels=5, 
                yticklabels=5,
                cbar_kws={'label': 'Cosine Similarity'})
    
    plt.title("Mem Hidden State: Cross-Layer Cosine Similarity")
    plt.xlabel("Layer Index")
    plt.ylabel("Layer Index")
    
    # 特别标注第 33 层 (Layer 34)
    # plt.axvline(x=33, color='red', linestyle='--', alpha=0.6, label='Layer 33')
    # plt.axhline(y=33, color='red', linestyle='--', alpha=0.6)
    
    plt.show()
    
    # 4. 打印相邻层相似度 (检查演化速度)
    print("Adjacent Layer Similarity (Evolution Speed):")
    adj_sim = np.diag(sim_matrix, k=1)
    for i, s in enumerate(adj_sim):
        if i >= 30: # 重点关注最后几层
            print(f"Layer {i} -> {i+1}: {s:.4f}")
            
    return sim_matrix

# 直接调用
sim_mat = analyze_mem_hidden_similarity(past_key_values.mem_hidden)
# Out:
# Adjacent Layer Similarity (Evolution Speed):
# Layer 30 -> 31: 0.9635
# Layer 31 -> 32: 0.9663
# Layer 32 -> 33: 0.9634
# Layer 33 -> 34: 0.9584
# Layer 34 -> 35: 0.2553

# %%
# 定义存储容器
internal_updates = {}

def get_activation(name):
    def hook(model, input, output):
        # 捕获 Attention 之后的残差和 (即进入 MLP 之前的状态)
        internal_updates[name] = output.detach()
    return hook

# 为最后两层注册 Hook (针对 Qwen2 结构)
# 注意：Qwen2 的 block 结构通常是 model.layers[i]
model.model.layers[33].post_attention_layernorm.register_forward_hook(get_activation('L33_post_attn'))
model.model.layers[34].post_attention_layernorm.register_forward_hook(get_activation('L34_post_attn'))
model.model.layers[35].post_attention_layernorm.register_forward_hook(get_activation('L35_post_attn'))

# 执行一次推理 (使用你的 Viaweb 样本)
with torch.no_grad():
    outputs = model(**inputs,output_hidden_states=True)

def detailed_component_analysis(hidden_states, internal_updates, layer_idx, pos=128):
    # h_in: 进入该层的状态
    h_in = hidden_states[layer_idx][0, pos, :]
    # h_mid: Attention 之后, MLP 之前的状态
    h_mid = internal_updates[f'L{layer_idx}_post_attn'][0, pos, :]
    # h_out: 该层最终输出状态
    h_out = hidden_states[layer_idx+1][0, pos, :]
    
    attn_update_norm = torch.norm(h_mid - h_in).item()
    mlp_update_norm = torch.norm(h_out - h_mid).item()
    
    print(f"--- Layer {layer_idx} Detailed Analysis (Pos {pos}) ---")
    print(f"Attention Update Norm: {attn_update_norm:.4f}")
    print(f"MLP Update Norm:       {mlp_update_norm:.4f}")

l = 34
detailed_component_analysis(outputs.hidden_states, internal_updates, l, pos=128)
detailed_component_analysis(outputs.hidden_states, internal_updates, l, pos=-1)
# Out:
# --- Layer 34 Detailed Analysis (Pos 128) ---
# Attention Update Norm: 244.0000
# MLP Update Norm:       280.0000
# --- Layer 34 Detailed Analysis (Pos -1) ---
# Attention Update Norm: 240.0000
# MLP Update Norm:       292.0000

# %%
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
import seaborn as sns

def analyze_layer_pooling_effect(hidden_states, layer_idx=35):
    """
    分析特定层是否发生了全局表征对齐（池化效应）
    hidden_states: tuple, 模型输出的 hidden_states
    layer_idx: 要分析的层索引
    """
    # 1. 提取 Layer 35 的输出 [batch, seq_len, hidden_size]
    # 注意：hidden_states[i] 对应第 i-1 层的输出
    h = hidden_states[layer_idx+1][0].detach().float() # [seq_len, hidden_size]
    seq_len = h.size(0)
    
    # 2. 计算两两之间的余弦相似度矩阵
    # 归一化后进行矩阵乘法: S = (h / |h|) @ (h / |h|)^T
    h_norm = F.normalize(h, p=2, dim=1)
    sim_matrix = torch.mm(h_norm, h_norm.T).cpu().numpy()
    
    # 3. 计算全局平均相似度（排除对角线）
    mask = ~torch.eye(seq_len, dtype=torch.bool)
    avg_sim = sim_matrix[mask.cpu().numpy()].mean()
    
    # 4. 可视化
    plt.figure(figsize=(12, 10))
    sns.heatmap(sim_matrix, cmap='magma', vmin=0.5, vmax=1.0) # 重点观察 0.5 以上的区域
    plt.title(f"Layer {layer_idx} Pairwise Hidden Similarity (Pooling Effect Analysis)")
    plt.xlabel("Token Index")
    plt.ylabel("Token Index")
    
    # 特别标记出 Memory Token 的位置
    plt.axvline(x=128, color='cyan', linestyle='--', alpha=0.5, label='Mem Position')
    plt.axhline(y=128, color='cyan', linestyle='--', alpha=0.5)
    
    print(f"Layer {layer_idx} Average Inter-token Similarity: {avg_sim:.4f}")
    plt.show()
    
    return sim_matrix, avg_sim

# 使用：
sim_mat, avg_s = analyze_layer_pooling_effect(outputs.hidden_states, layer_idx=32)
# Out:
# Layer 32 Average Inter-token Similarity: 0.7578

# %%
import torch
import pandas as pd

def analyze_hidden_deltas(hidden_states, mem_pos=128, normal_pos=-1):
    """
    hidden_states: 包含所有层输出的元组
    mem_pos: memory token 的索引
    normal_pos: 一个普通 token (如噪声序列中的一个) 的索引做对比
    """
    stats = []
    num_layers = len(hidden_states)
    
    for i in range(1, num_layers):
        # 提取当前层和前一层的向量
        h_prev = hidden_states[i-1][0, :, :] # [seq, dim]
        h_curr = hidden_states[i][0, :, :]
        
        # 计算总增量向量: delta = h_{l} - h_{l-1}
        delta_vec = h_curr - h_prev
        
        # 提取特定位置的统计信息
        mem_delta_norm = torch.norm(delta_vec[mem_pos, :]).item()
        norm_delta_norm = torch.norm(delta_vec[normal_pos, :]).item()
        
        mem_base_norm = torch.norm(h_prev[mem_pos, :]).item()
        norm_base_norm = torch.norm(h_prev[normal_pos, :]).item()
        
        stats.append({
            "Layer": i,
            "Mem_Delta_Norm": mem_delta_norm,
            "Normal_Delta_Norm": norm_delta_norm,
            "Mem_Update_Ratio": mem_delta_norm / mem_base_norm, # 更新强度比
            "Normal_Update_Ratio": norm_delta_norm / norm_base_norm # 更新强度比
        })
    
    df = pd.DataFrame(stats)
    # 重点查看最后几层
    # print(df.tail(5))
    return df

df_delta = analyze_hidden_deltas(outputs.hidden_states)
df_delta.tail(5)
# Out:
#     Layer  Mem_Delta_Norm  Normal_Delta_Norm  Mem_Update_Ratio  \
# 31     32           58.75               68.0          0.335714
# 32     33           69.00               64.0          0.338235
# 33     34           69.00               69.5          0.285124
# 34     35           88.50               77.5          0.343023
# 35     36          298.00              286.0          1.006757
#
#     Normal_Update_Ratio
# 31             0.475524
# 32             0.349727
# 33             0.311659
# 34             0.298077
# 35             0.922581
